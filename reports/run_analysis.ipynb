# %%
import awkward as ak
import numba as nb
import numpy as np
import vector
vector.register_awkward()

from src.analysis.plot import calc_pur_eff, plot_pur_eff_w_dict

# %%
target_file = "/storage/af/user/tsievert/topNet/SPAtop/data/delphes/v4/tt_hadronic_testing_SLIMMED.h5"
pred_files = {
    'chi2': "/storage/af/user/tsievert/topNet/SPAtop/data/delphes/v4/tt_hadronic_baseline.h5",
    'SPAtop': "/storage/af/user/tsievert/topNet/SPAtop/data/delphes/v4/tt_hadronic_predict.h5",
    # 'chi2': "/storage/af/user/tsievert/topNet/SPAtop/data/delphes/v4/tt_hadronic_baseline.h5",
}

bins = np.arange(0, 1000, 100)
bin_centers = [(bins[i] + bins[i + 1]) / 2 for i in range(bins.size - 1)]
xerr = (bins[1] - bins[0]) / 2 * np.ones(bins.shape[0] - 1)

# %%
plot_pur_eff_w_dict(
    pred_files, target_file, 
    save_path="/storage/af/user/tsievert/topNet/SPAtop/reports", 
    proj_name='SPAtop',
    # bins_dict={
    #     'FR': np.arange(0, 300, 10),
    #     'SRqq': np.arange(100, 400, 10),
    #     'SRbq': np.arange(100, 400, 10),
    #     'FB': np.arange(200, 1000, 50),
    #     'all': np.arange(0, 1000, 50),
    # }
)
# Out:
# Processing SPAtop
# Number of Boosted Prediction: 104505
# Number of Resolved Prediction before OR: 85072
# Number of Resolved Prediction after OR: 76980
# Number of Semi-Resolved-qq Prediction before OR: 62639
# Number of Semi-Resolved-qq Prediction after OR: 56859
# Number of Semi-Resolved-bq Prediction before OR: 25825
# Number of Semi-Resolved-bq Prediction after OR: 23053
# Processing chi2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/topNet/SPAtop/src/analysis/boosted.py:142, in parse_boosted_w_target(testfile, predfile)
#     141 # FBt detection probability
# --> 142 dp_FBt1 = np.array(predfile["TARGETS"]["FBt1"]["detection_probability"])
#     143 dp_FBt2 = np.array(predfile["TARGETS"]["FBt2"]["detection_probability"])
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/topNet/spatop_venv/lib64/python3.9/site-packages/h5py/_hl/group.py:357, in Group.__getitem__(self, name)
#     356 elif isinstance(name, (bytes, str)):
# --> 357     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358 else:
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5o.pyx:241, in h5py.h5o.open()
#
# KeyError: "Unable to synchronously open object (object 'detection_probability' doesn't exist)"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plot_pur_eff_w_dict(
#       2     pred_files, target_file,
#       3     save_path="/storage/af/user/tsievert/topNet/SPAtop/reports",
#       4     proj_name='SPAtop',
#       5     # bins_dict={
#       6     #     'FR': np.arange(0, 300, 10),
#       7     #     'SRqq': np.arange(100, 400, 10),
#       8     #     'SRbq': np.arange(100, 400, 10),
#       9     #     'FB': np.arange(200, 1000, 50),
#      10     #     'all': np.arange(0, 1000, 50),
#      11     # }
#      12 )
#
# File ~/topNet/SPAtop/src/analysis/plot.py:286, in plot_pur_eff_w_dict(plot_dict, target_path, save_path, proj_name, bins_dict)
#     284 for tag, pred_path in plot_dict.items():
#     285     print("Processing", tag)
# --> 286     results, SR_condition = calc_pur_eff(target_path, pred_path, bins_dict)
#     288     # merged
#     289     ax_m[0].errorbar(
#     290         x=bin_centers_dict['all'], y=results["pur_m"], xerr=xerr_dict['all'], yerr=results["purerr_m"], fmt="o", capsize=5, label=tag
#     291     )
#
# File ~/topNet/SPAtop/src/analysis/plot.py:27, in calc_pur_eff(target_path, pred_path, bins_dict)
#      23 SR_condition = any("SR" in key for key in pred_h5["TARGETS"].keys())
#      25 ## generate look up tables ##
#      26 # boosted
# ---> 27 LUT_boosted_pred, LUT_boosted_target, vfjs_reco = parse_boosted_w_target(target_h5, pred_h5)
#      28 # semi-resolved
#      29 if SR_condition:
#
# File ~/topNet/SPAtop/src/analysis/boosted.py:157, in parse_boosted_w_target(testfile, predfile)
#     151 bqq_FBt2_p = np.array(predfile["TARGETS"]["FBt2"]["bqq"]) + (N_AK4_JETS + N_AK8_JETS)
#     153 # boosted top detection probability
#     154 dp_FBt1 = np.array(
#     155     np.logical_and(
#     156         predfile["TARGETS"]["FBt1"]["mask"],
# --> 157         predfile["TARGETS"]["FBt1"]["chi2"] < BOOSTED_CHI2_CUT
#     158     )
#     159 ).astype("float")
#     160 dp_FBt2 = np.array(
#     161     np.logical_and(
#     162         predfile["TARGETS"]["FBt2"]["mask"],
#     163         predfile["TARGETS"]["FBt2"]["chi2"] < BOOSTED_CHI2_CUT
#     164     )
#     165 ).astype("float")
#     167 # veryfatjet assignment probability
#
# TypeError: '<' not supported between instances of 'Dataset' and 'int'
